# %%
import pandas as pd
from easyimages import EasyImageList, EasyImage
from easyimages.utils import make_notebook_wider

# %%
make_notebook_wider()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
json_path = "/home/SharedFolder/CurrentDatasets/bdd100k_sorted/annotations/bdd100k_sorted_train_dev_C_over.json"
image_base_path = "/home/SharedFolder/CurrentDatasets/bdd100k_sorted/train_dev_C/"

# %%
df = pd.read_json(json_path)
df = df.reset_index(drop = True)
df["weather"] = pd.DataFrame(df['attributes'].tolist())["weather"]
df = df.drop(columns = ["attributes", "labels", "timestamp"]).reset_index(drop = True)
df["name"] = image_base_path + df["name"]

# %%
# Snowy
image_list = df[df["weather"] == "snowy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 499 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/5141bb06-a6090cd4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/32e9754a-c29ee4ed.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/67d56942-46e522a6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/b784ff27-58c39a23.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/8d785c2e-74cee2dd.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/06f7a41e-c8b5c7c7.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/5621341c-b3922eab.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/8d9a50af-f357249f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/b784ff27-58c39a23.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/007c01ea-63aa326c.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3cfdf1e3-b5ad0e37.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/58f77276-ac3c1837.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a5054b30-833c7db3.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/87274502-153725dd.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3cfdf1e3-b5ad0e37.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/191538e6-34f45c3b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/9b18aec9-a9ca67bf.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/707eec9c-6fcb6840.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/bf4af26f-12121f1d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/bf4af26f-12121f1d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/32e9754a-c29ee4ed.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/26aba080-04d79638.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/38fb606f-95e5a75d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/8959b96d-6889016f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/62a5ec72-faf4fd7b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Rainy
image_list = df[df["weather"] == "rainy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 498 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/271b4ca8-35114a44.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/08952c41-cd2886c9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/4ff13f5f-10fb88a0.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/2bf20261-03c24bba.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/4ff13f5f-10fb88a0.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/543fc7b7-019c4c21.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/0ad99aa9-20ddd733.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3da75143-9e669c56.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/12bf2cad-3560a7a6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/b403b27c-37cac4b8.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/c76d86ec-f11c0df0.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/2740c139-838de60f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/6d26b3fa-e32207da.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/543fc7b7-019c4c21.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/19493744-fab3b4e6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/c76d86ec-f11c0df0.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/6d26b3fa-e32207da.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/85f3b428-a6f47298.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a44d7cba-2e4da855.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3cdbef52-4739af31.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/b403b27c-37cac4b8.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/63ff7328-5a28a775.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/7ecb7e79-b092fd0d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/08952c41-cb9f493d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/33acd32e-cee57719.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Cloudy
image_list = df[df["weather"] == "cloudy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 498 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a1555d5a-42ac7fdc.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/1f6e55bb-49cb412b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/583d3e3f-e03f3e26.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/86a03760-5dc26a0b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/7bf75f54-c801a894.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/6c1f5e8c-0d0eedd7.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/0908dd6b-47e1a421.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a84f215d-58be40a4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/ac9be3fe-790d46f9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/355f56e4-d393ce69.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/696a8709-17963d76.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/743507a7-9c924371.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/9e11d34b-cc31ce04.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/159ca82e-820d7a5f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/c0ddc0e1-c0c70d00.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/6e82a572-2a1709f8.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/c2eb2ca4-fc64114e.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3d881215-aa50ca40.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/2ff2d0b9-50e42da9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/65ae49f3-060b25d6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Clear
image_list = df[df["weather"] == "clear"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 500 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a45dc0a9-4b73b418.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3f0735e8-e233614f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/073d4e2a-55c1f733.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/6f50ac18-5c97d737.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/4246fadc-63b4fe19.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/be554fed-4ac78405.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/418c8b37-b221c63c.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/1465630c-46d49dce.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/49db75aa-8ce3e575.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/2c90dfd5-140baca2.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/bc92f518-fa316e88.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/521a1510-25af5168.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/4b2d9275-062e1b7b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/3f0735e8-e233614f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/68eae8d4-4631a30a.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/1c29669f-1237cc57.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/49b4a0a9-3e345439.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a4c6b745-eaa4f49d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/187631f3-fa0ac1b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/a482d132-68f334d4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/49b4a0a9-3e345439.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/7975e4cd-bf4998a1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/c21334d5-c0e77c4e.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/9452593e-bcda80af.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_C/57c4b923-d6f7a0b3.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...
