# %%
import pandas as pd
from easyimages import EasyImageList, EasyImage
from easyimages.utils import make_notebook_wider

# %%
make_notebook_wider()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
json_path = "/home/SharedFolder/CurrentDatasets/bdd100k_sorted/annotations/bdd100k_sorted_train_dev_B_over.json"
image_base_path = "/home/SharedFolder/CurrentDatasets/bdd100k_sorted/train_dev_B/"

# %%
df = pd.read_json(json_path)
df = df.reset_index(drop = True)
df["weather"] = pd.DataFrame(df['attributes'].tolist())["weather"]
df = df.drop(columns = ["attributes", "labels", "timestamp"]).reset_index(drop = True)
df["name"] = image_base_path + df["name"]

# %%
# Snowy
image_list = df[df["weather"] == "snowy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 498 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/17ffc2bb-e46a68f9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/6fa2874e-4939d7ea.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/ad1be482-d8ab7370.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/2332ba2c-be5321f8.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3de9984e-ceddca55.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a5054b30-833c7db3.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/58ff7092-9694faee.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3fc4ffaf-d50f9cb1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/5d2d790d-3d1ba958.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b36a5c73-437be32a.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/9c28931a-1ee7dbd4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/5a463e45-8a75f5e9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/32e9754a-c29ee4ed.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/32e9754a-c29ee4ed.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b4b47b81-90c3dbae.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3cfdf1e3-b5ad0e37.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/ae4fe4f5-0a4b9f85.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3d9a7d38-bc9633ae.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/67d446b2-3489f29a.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/32e9754a-c29ee4ed.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/2912a02e-e5b1a6ad.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/128a6c14-7c985c35.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/115d9e12-fd31cd1b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b7a9b166-7d9db10e.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/460e4d2e-1e653067.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Rainy
image_list = df[df["weather"] == "rainy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 498 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/8cf268f5-8c45b77f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/6312c033-b6366437.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/08952c41-cd2886c9.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/ba1f5489-3f8e2762.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/bb5cc516-eb91e8c8.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/24176f41-f90427e4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b336bdb9-ed5d2cc3.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a5dd241e-f9c71d5c.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/9fe3497b-de8a31a6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/75316b56-ac37af74.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/21c2a1fd-944077ef.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3410f7de-a897df8f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/45ad1aaa-c9178764.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3410f7de-a897df8f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/0ad99aa9-20ddd733.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/8cf268f5-8c45b77f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/6e8e4306-09bbc963.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/150d9bb9-97941256.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/c3b60e81-b28ef868.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/020cc8f8-8b679d0b.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/c5d864fa-3b452090.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/2bf20261-03c24bba.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/95c23d07-a7074591.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/317b521f-8e4268dc.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3410f7de-a897df8f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Cloudy
image_list = df[df["weather"] == "cloudy"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 498 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/06ab90be-453ee4a0.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a59e867f-b3cb850d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b61fda8b-fc0a3fe7.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/986151b1-0c0138d2.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/03aa1144-5efc1938.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a50c2f45-7a96a63c.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/990738d0-8b7c7819.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/12682475-b76c58cb.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b643ea5a-af37c824.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a0e85074-d06355bc.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a788f943-c9a37d38.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/a0100e62-b296186c.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/228330f4-1199dc8d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/986151b1-0c0138d2.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/696a8709-17963d76.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/827ce8e3-101b64b1.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...

# %%
# Clear
image_list = df[df["weather"] == "clear"]["name"].tolist()
image_list = [EasyImage.from_file(image, lazy = True) for image in image_list]
EL = EasyImageList(image_list)
EL
# Out:
# <ImageList with 499 EasyImages [filter OFF]>

# %%
EL.html(size = 75, sample = 400)
# Out:
# <img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/549a6ea6-80c28111.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/188e4f84-e7c7db54.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/0c5faf8b-aeceb406.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/8a0f8a0f-670d637f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/3c39180d-d84dfdb4.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/c174b1bd-2a882560.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/1b02f4f3-856fcf8d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/afd35d01-4f0f5070.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/0af6039a-f3c91319.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/c24da7c7-21c58e17.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/8995ce22-b46b17e3.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/c7f8589f-45c47b58.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/572ce409-d87c3078.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/60c678e7-4813ae0f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/1012f4eb-cc13162e.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/419ad787-18d2b137.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/8fb57a8a-54e58dae.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/5fd3e10a-3e1eabd6.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/4678b0d5-54292c6f.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/4ef18c1b-8c2c9719.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/073d4e2a-55c1f733.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/83a108ea-e8bfcd25.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b612e792-38fc9d6d.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/39f85889-0ea2a689.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_dev_B/b2743b5d-e2d585be.jpg'/><img style='width: 75px; height: 75px; margin: 1px; float: left; border: 0px solid black;'title=[] src='bdd100k_sorted/train_ ...
